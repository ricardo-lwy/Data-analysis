# %%
from bs4 import BeautifulSoup  # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import urllib.request
import re
import pandas as pd
from pandas.core.frame import DataFrame
from openpyxl.writer.excel import ExcelWriter
from lxml import etree
import requests  # 模拟浏览器请求的库
import re  # 正则库aaa@qq.com
from ast import Break
from http.client import NOT_FOUND
import re
header = {
    'user-agent': 'Mozilla/5.0(Macinatosh;Intel Mac OS X 10_13_6)Applewebkit/537.36(KHTML,like Gecko)Chrome/81.0.4044.138 Safari/537.36',
}

# %%
all_url = [
"https://bohm-paris.com/collections/colliers/products/collier-multirang-bohm-paris-salvador",
"https://bohm-paris.com/collections/colliers/products/collier-multirang-bohm-paris-salvador?variant=39533136314550",
"https://bohm-paris.com/collections/colliers/products/collier-multirang-bohm-paris-salvador?variant=39533136347318",
"https://bohm-paris.com/collections/colliers/products/collier-multirang-bohm-paris-salvador?variant=39533136412854",
"https://bohm-paris.com/collections/colliers/products/collier-multirang-bohm-paris-salvador?variant=42555842920660",
"https://bohm-paris.com/products/collier-bohm-paris-surffyla?variant=40110547075254",
"https://bohm-paris.com/products/collier-bohm-paris-surffyla?variant=40110547108022",
"https://bohm-paris.com/products/collier-bohm-paris-surffyla?variant=40110547140790",
"https://bohm-paris.com/products/collier-bohm-paris-surffyla?variant=40110547173558",
"https://bohm-paris.com/products/collier-bohm-paris-surffyla?variant=40110547206326",
"https://bohm-paris.com/collections/boucles-doreilles/products/mono-boucles-bohm-paris-earcuff-horine",
"https://bohm-paris.com/collections/boucles-doreilles/products/mono-boucles-bohm-paris-earcuff-horine?variant=42816233701588",
"https://bohm-paris.com/collections/boucles-doreilles/products/boucles-bohm-paris-isia?variant=42552578212052",
"https://bohm-paris.com/collections/boucles-doreilles/products/boucles-bohm-paris-isia?variant=42552578244820",
"https://bohm-paris.com/collections/boucles-doreilles/products/boucles-bohm-paris-isia?variant=42552578277588",
"https://bohm-paris.com/collections/boucles-doreilles/products/boucles-bohm-paris-isia?variant=42552578310356",
"https://bohm-paris.com/products/boucles-bohm-paris-puce-bohmys?variant=39256655691958",
"https://bohm-paris.com/products/boucles-bohm-paris-puce-bohmys?variant=39256655659190",
"https://bohm-paris.com/collections/colliers/products/collier-bohm-paris-lyllian",
"https://bohm-paris.com/collections/colliers/products/collier-bohm-paris-lyllian?variant=40517967511734",
"https://bohm-paris.com/collections/colliers/products/collier-bohm-paris-hendie?variant=42057601646804",
"https://bohm-paris.com/collections/colliers/products/collier-bohm-paris-hendie?variant=42057601614036",
"https://bohm-paris.com/collections/colliers/products/collier-bohm-paris-zackary?variant=39262082629814",
"https://bohm-paris.com/collections/colliers/products/collier-bohm-paris-zackary?variant=39262082662582",
"https://bohm-paris.com/products/bracelet-bohm-paris-alicianne?variant=42555157971156",
"https://bohm-paris.com/products/bracelet-bohm-paris-alicianne?variant=42555158003924",
"https://bohm-paris.com/products/bracelet-bohm-paris-alicianne?variant=42555158036692",
"https://bohm-paris.com/products/bracelet-bohm-paris-alicianne?variant=42555158069460",
"https://bohm-paris.com/products/bracelet-bohm-paris-mirha?variant=40853948334262",
"https://bohm-paris.com/products/bracelet-bohm-paris-mirha?variant=40853948367030",
"https://bohm-paris.com/products/bracelet-bohm-paris-mirha?variant=40853948399798",
"https://bohm-paris.com/products/bracelet-bohm-paris-mirha?variant=40853948432566",
"https://bohm-paris.com/collections/bracelets/products/bracelet-bohm-paris-aaliyah?variant=42900069548244",
"https://bohm-paris.com/collections/bracelets/products/bracelet-bohm-paris-aaliyah?variant=42900069581012",
"https://bohm-paris.com/products/bracelet-bohm-paris-beata?variant=31557

"https://bohm-paris.com/collections/boucles-doreilles/products/boucles-bohm-paris-lea?variant=32106217046083",
"https://bohm-paris.com/collections/boucles-doreilles/products/boucles-bohm-paris-lea?variant=32106217177155",

]

# %%
link = DataFrame(all_url)
link
# Out:
#                                                      0
# 0    https://bohm-paris.com/collections/colliers/pr...
# 1    https://bohm-paris.com/collections/colliers/pr...
# 2    https://bohm-paris.com/collections/colliers/pr...
# 3    https://bohm-paris.com/collections/colliers/pr...
# 4    https://bohm-paris.com/collections/colliers/pr...
# ..                                                 ...
# 112  https://bohm-paris.com/collections/boucles-dor...
# 113  https://bohm-paris.com/collections/boucles-dor...
# 114  https://bohm-paris.com/collections/boucles-dor...
# 115  https://bohm-paris.com/collections/boucles-dor...
# 116  https://bohm-paris.com/collections/boucles-dor...
#
# [117 rows x 1 columns]

# %%
# 15/09/2022 爬取bohm测试

from cgitb import html


result1 = []
linksname = []
link = DataFrame(all_url)
print(len(all_url))
for url in all_url:
    linksname.append(url)
    try:
        soup = BeautifulSoup(requests.get(url).text, "html.parser")
       

        # 通过查看字段发现它在第12项,但是暂时用不到
        #xpath方法好像也实现不了

    # 无货<button type="submit" data-use-primary-button="true" class="ProductForm__AddToCart Button Button--secondary Button--full" disabled="disabled">Rupture</button>
    # 有货<button type="submit" data-use-primary-button="true" class="ProductForm__AddToCart Button Button--primary Button--full" data-action="add-to-cart"><span>Ajouter au panier</span></button>
    # 有货警报<button type="submit" data-use-primary-button="true" class="ProductForm__AddToCart Button Button--primary Button--full" data-action="add-to-cart"><span>Ajouter au panier</span></button>
       # 网站特性，可以通过第一个submit值来判断
       #语法规则find('tag域'，{tag中的参数})
        buttontest = soup.find('button', {"type": "submit"})
        etat = [x.get_text() for x in buttontest]
        etatstr = etat[0]
        # 无货的情况
        if (etatstr == "Rupture"):
            result1.append("无货")
            print("无货")

        else:
            # 有货，未正确显示
            try:
                ptest = soup.find(
                    'p', {"class": "ProductForm__Inventory Text--subdued", "style": "display: none"})
                 
                p_str = [x.get_text() for x in ptest] #执行不了就跳出
                result1.append("货源充足")
                print("货源充足")
               

             # 有货，马上没货
           
            except:
                
                ptest = soup.find(
                    'p', {"class": "ProductForm__Inventory Text--subdued"})
                p_str = [x.get_text() for x in ptest]
                #匹配数字
                #p_num = re.findall(r"\d+",p_str)
                result1.append(p_str)
                print(p_str)

    except:
        result1.append("notfound")
        print("notOKOK")


df_pm = DataFrame({'linksname': linksname, '剩余数量': result1})

df_pm
# Out:
# 117
# ['Seulement 5 exemplaires en stock !']
# 货源充足
# 货源充足
# 货源充足
# ['Seulement 1 exemplaire en stock !']
# 货源充足
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 5 exemplaires en stock !']
# ['Seulement 3 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 3 exemplaires en stock !']
# ['Seulement 3 exemplaires en stock !']
# ['Seulement 3 exemplaires en stock !']
# ['Seulement 5 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 4 exemplaires en stock !']
# ['Seulement 5 exemplaires en stock !']
# ['Seulement 5 exemplaires en stock !']
# ['Seulement 3 exemplaires en stock !']
# ['Seulement 2 exemplaires en stock !']
# ['Seulement 3 exemplaires en stock !']
# ...

# %%
df_pm.to_excel('./BOHM.xlsx')
