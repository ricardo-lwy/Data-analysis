# %%
#!pip install requests
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import urllib.request
import re
import pandas as pd
from pandas.core.frame import DataFrame
from openpyxl.writer.excel import ExcelWriter

import requests#模拟浏览器请求的库
import re#正则库aaa@qq.com
header={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
}

# %%
all_url=[
"https://www.linkody.com/en/seo-tools/website-authority/bijoux-annuaire.com",


]

# %%
link=DataFrame(all_url)
link
# Out:
#                                                    0
# 0  https://www.linkody.com/en/seo-tools/website-a...

# %%
from ast import Break
from http.client import NOT_FOUND



titles=[]
all_lang=[]
linksname=[]
link=DataFrame(all_url)
print(len(all_url))
for url in all_url:
    linksname.append(url)
    try:
        soup = BeautifulSoup(requests.get(url).text,"html.parser")
     
        title = soup.find('title')
        title_str=[x.get_text() for x in title]
        
##最终版本（可能），还可能要考虑一些长时间无响应的网站，看是否要添加计时器，
        for link in soup.find_all('html'):
            all_lang.append(link.get('lang'))
            titles.append(title_str)
            print("OKOK")
            break
        
           
    except:
        titles.append("notfound")
        all_lang.append("unknow")
        print("notOKOK")

df_pm=DataFrame({'linksname': linksname,'titles':titles,'all_lang':all_lang})

df_pm
# Out:
# 1
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Website Authority Checker - Check DA, TF, CF &amp; Spam Score of any website - Linkody" name="title"/>
# <meta content="This free SEO tool will give you several metrics to assess the autority of any website: the Citation Flow and Trust Flow from Majestic, the Domain Autority and Spam Score from Moz, and the number of backlinks and referring domains." name="description"/>
# <meta content="index, follow" name="robots"/>
# <title>Website Authority Checker - Check DA, TF, CF &amp; Spam Score of any website - Linkody</title>
# <link href="/css/main.css?20220616" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/css/icons.css?20220616" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/images/favicon.ico?20220616" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
df_pm.to_excel('./product_titlenew1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Bureaux\codes\网页数据爬取 - Copie.ipynb Cellule 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Bureaux/codes/%E7%BD%91%E9%A1%B5%E6%95%B0%E6%8D%AE%E7%88%AC%E5%8F%96%20-%20Copie.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df_pm.to_excel('./product_titlenew1.xlsx')
#
# NameError: name 'df_pm' is not defined
